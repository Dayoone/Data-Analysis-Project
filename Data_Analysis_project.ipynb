# %% [markdown]
# <a href="https://colab.research.google.com/github/Dayoone/Data-Analysis-Project/blob/main/Data_Analysis_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA analysis for Company XYZ
#
# Noted that Company XYZ owns a supermarket chain across the country.Each major branch located in 3 cities across the country recorded sales information for 3 months, to help the company understand sales trends and determine its growth, as the rise of supermarkets competition is seen to increase.
#
# The data folder contains datasets from three different branches; Lagos, Abuja and Port Harcourt. Each data file from the branches contains the same attribute information

# %% [markdown]
# **Project Steps**
#
#
# To caery out the analysis, all the necessary and relevant libraries were imported on the jupiter Notebook using pandas. the libraries includes: numpy, pandas, seaborn, matplotlib. etc. The XYZ company project was carried out in the following steps:

# %% [markdown]
# **STEP ONE**
#
# Loading Datasets

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **EXTRACTION OF DATASETS**
#
# We are obtaining the dataset from repository Github as directed in the Project folder

# %%
url = "https://github.com/bleso-a/Data-Analysis-Project/blob/main/Abuja_Branch.csv"

# %%
Branch_A = pd.read_html(url)

# %%
Branch_A # Check the content of the Branch A (Abuja Branch)
# Out:
# [     Unnamed: 0   Invoice ID Branch   City Customer type  Gender  \
#  0           NaN  692-92-5582      B  Abuja        Member  Female
#  1           NaN  351-62-0822      B  Abuja        Member  Female
#  2           NaN  529-56-3974      B  Abuja        Member    Male
#  3           NaN  299-46-1805      B  Abuja        Member  Female
#  4           NaN  319-50-3348      B  Abuja        Normal  Female
#  ..          ...          ...    ...    ...           ...     ...
#  327         NaN  552-44-5977      B  Abuja        Member    Male
#  328         NaN  430-53-4718      B  Abuja        Member    Male
#  329         NaN  602-16-6955      B  Abuja        Normal  Female
#  330         NaN  690-01-6631      B  Abuja        Normal    Male
#  331         NaN  303-96-2227      B  Abuja        Normal  Female
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
#  0        Food and beverages     19742.4         3   2961.36   62188.56
# ...

# %% [markdown]
# **CONVERT THE SERIES TO DATAFRAME**

# %%
len(Branch_A)
# Out:
# 1

# %%
Abuja_branch = Branch_A[0]

# %%
Abuja_branch.head()
# Out:
#    Unnamed: 0   Invoice ID Branch   City Customer type  Gender  \
# 0         NaN  692-92-5582      B  Abuja        Member  Female
# 1         NaN  351-62-0822      B  Abuja        Member  Female
# 2         NaN  529-56-3974      B  Abuja        Member    Male
# 3         NaN  299-46-1805      B  Abuja        Member  Female
# 4         NaN  319-50-3348      B  Abuja        Normal  Female
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0      Food and beverages     19742.4         3   2961.36   62188.56
# 1     Fashion accessories      5212.8         4   1042.56   21893.76
# 2  Electronic accessories      9183.6         4   1836.72   38571.12
# 3       Sports and travel     33739.2         6  10121.76  212556.96
# 4      Home and lifestyle     14508.0         2   1450.80   30466.80
#
#         Date   Time Payment      cogs  gross margin percentage  gross income  \
# 0  2/20/2019  13:27    Card   59227.2                 4.761905       2961.36
# ...

# %% [markdown]
# **DELETE THE UNNAMED COLUMN**

# %%
del Abuja_branch['Unnamed: 0']

# %%
Abuja_branch.head()
# Out:
#     Invoice ID Branch   City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Abuja        Member  Female      Food and beverages
# 1  351-62-0822      B  Abuja        Member  Female     Fashion accessories
# 2  529-56-3974      B  Abuja        Member    Male  Electronic accessories
# 3  299-46-1805      B  Abuja        Member  Female       Sports and travel
# 4  319-50-3348      B  Abuja        Normal  Female      Home and lifestyle
#
#    Unit price  Quantity    Tax 5%      Total       Date   Time Payment  \
# 0     19742.4         3   2961.36   62188.56  2/20/2019  13:27    Card
# 1      5212.8         4   1042.56   21893.76   2/6/2019  18:07    Epay
# 2      9183.6         4   1836.72   38571.12   3/9/2019  17:03    Cash
# 3     33739.2         6  10121.76  212556.96  1/15/2019  16:19    Cash
# 4     14508.0         2   1450.80   30466.80  3/11/2019  15:30    Epay
#
#        cogs  gross margin percentage  gross income  Rating
# ...

# %% [markdown]
# INSERT SERIAL NUMBER

# %%
Abuja_branch.insert(loc = 0, column = "Serial_Number", value = np.arange(1,333))

# %%
Abuja_branch
# Out:
#      Serial_Number   Invoice ID Branch   City Customer type  Gender  \
# 0                1  692-92-5582      B  Abuja        Member  Female
# 1                2  351-62-0822      B  Abuja        Member  Female
# 2                3  529-56-3974      B  Abuja        Member    Male
# 3                4  299-46-1805      B  Abuja        Member  Female
# 4                5  319-50-3348      B  Abuja        Normal  Female
# ..             ...          ...    ...    ...           ...     ...
# 327            328  552-44-5977      B  Abuja        Member    Male
# 328            329  430-53-4718      B  Abuja        Member    Male
# 329            330  602-16-6955      B  Abuja        Normal  Female
# 330            331  690-01-6631      B  Abuja        Normal    Male
# 331            332  303-96-2227      B  Abuja        Normal  Female
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0        Food and beverages     19742.4         3   2961.36   62188.56
# ...

# %% [markdown]
# **BRANCH_B**
#
# Second dataset for branch B(Lagos_Branch
# from Github.com and convert the dataSeries to DataFrame

# %%
url1 = "https://github.com/bleso-a/Data-Analysis-Project/blob/main/Lagos_Branch.csv"

# %%
Branch_B = pd.read_html(url1)

# %%
Branch_B
# Out:
# [     Unnamed: 0   Invoice ID Branch   City Customer type  Gender  \
#  0           NaN  750-67-8428      A  Lagos        Member  Female
#  1           NaN  631-41-3108      A  Lagos        Normal    Male
#  2           NaN  123-19-1176      A  Lagos        Member    Male
#  3           NaN  373-73-7910      A  Lagos        Normal    Male
#  4           NaN  355-53-5943      A  Lagos        Member  Female
#  ..          ...          ...    ...    ...           ...     ...
#  335         NaN  886-18-2897      A  Lagos        Normal  Female
#  336         NaN  745-74-0715      A  Lagos        Normal    Male
#  337         NaN  727-02-1313      A  Lagos        Member    Male
#  338         NaN  347-56-2442      A  Lagos        Normal    Male
#  339         NaN  849-09-3807      A  Lagos        Member  Female
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
#  0         Health and beauty     26888.4         7   9410.94  197629.74
# ...

# %%
len(Branch_B)
# Out:
# 1

# %%
Lagos_branch = Branch_B[0]

# %%
Lagos_branch.head()
# Out:
#    Unnamed: 0   Invoice ID Branch   City Customer type  Gender  \
# 0         NaN  750-67-8428      A  Lagos        Member  Female
# 1         NaN  631-41-3108      A  Lagos        Normal    Male
# 2         NaN  123-19-1176      A  Lagos        Member    Male
# 3         NaN  373-73-7910      A  Lagos        Normal    Male
# 4         NaN  355-53-5943      A  Lagos        Member  Female
#
#              Product line  Unit price  Quantity    Tax 5%      Total  \
# 0       Health and beauty     26888.4         7   9410.94  197629.74
# 1      Home and lifestyle     16678.8         7   5837.58  122589.18
# 2       Health and beauty     20959.2         8   8383.68  176057.28
# 3       Sports and travel     31071.6         7  10875.06  228376.26
# 4  Electronic accessories     24782.4         6   7434.72  156129.12
#
#         Date   Time Payment      cogs  gross margin percentage  gross income  \
# 0   1/5/2019  13:08    Epay  188218.8                 4.761905       9410.94
# ...

# %%
del Lagos_branch["Unnamed: 0"]

# %%
Lagos_branch
# Out:
#       Invoice ID Branch   City Customer type  Gender            Product line  \
# 0    750-67-8428      A  Lagos        Member  Female       Health and beauty
# 1    631-41-3108      A  Lagos        Normal    Male      Home and lifestyle
# 2    123-19-1176      A  Lagos        Member    Male       Health and beauty
# 3    373-73-7910      A  Lagos        Normal    Male       Sports and travel
# 4    355-53-5943      A  Lagos        Member  Female  Electronic accessories
# ..           ...    ...    ...           ...     ...                     ...
# 335  886-18-2897      A  Lagos        Normal  Female      Food and beverages
# 336  745-74-0715      A  Lagos        Normal    Male  Electronic accessories
# 337  727-02-1313      A  Lagos        Member    Male      Food and beverages
# 338  347-56-2442      A  Lagos        Normal    Male      Home and lifestyle
# 339  849-09-3807      A  Lagos        Member  Female     Fashion accessories
#
# ...

# %%
Lagos_branch.insert(loc = 0, column = "Serial_Number", value = np.arange(333, 673))

# %%
Lagos_branch
# Out:
#      Serial_Number   Invoice ID Branch   City Customer type  Gender  \
# 0              333  750-67-8428      A  Lagos        Member  Female
# 1              334  631-41-3108      A  Lagos        Normal    Male
# 2              335  123-19-1176      A  Lagos        Member    Male
# 3              336  373-73-7910      A  Lagos        Normal    Male
# 4              337  355-53-5943      A  Lagos        Member  Female
# ..             ...          ...    ...    ...           ...     ...
# 335            668  886-18-2897      A  Lagos        Normal  Female
# 336            669  745-74-0715      A  Lagos        Normal    Male
# 337            670  727-02-1313      A  Lagos        Member    Male
# 338            671  347-56-2442      A  Lagos        Normal    Male
# 339            672  849-09-3807      A  Lagos        Member  Female
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0         Health and beauty     26888.4         7   9410.94  197629.74
# ...

# %% [markdown]
# **BRANCH_C**
#
# Third dataset for branch_C(PortHarcourt_Branch from Github.com and convert the dataSeries to DataFrame

# %%
url2 = "https://github.com/bleso-a/Data-Analysis-Project/blob/main/Port_Harcourt_Branch.csv"

# %%
Branch_C = pd.read_html(url2)

# %%
Branch_C
# Out:
# [     Unnamed: 0   Invoice ID Branch           City Customer type  Gender  \
#  0           NaN  226-31-3081      C  Port Harcourt        Normal  Female
#  1           NaN  699-14-3026      C  Port Harcourt        Normal    Male
#  2           NaN  315-22-5665      C  Port Harcourt        Normal  Female
#  3           NaN  300-71-4605      C  Port Harcourt        Member    Male
#  4           NaN  183-56-6882      C  Port Harcourt        Member  Female
#  ..          ...          ...    ...            ...           ...     ...
#  323         NaN  148-41-7930      C  Port Harcourt        Normal    Male
#  324         NaN  189-40-5216      C  Port Harcourt        Normal    Male
#  325         NaN  267-62-7380      C  Port Harcourt        Member    Male
#  326         NaN  652-49-6720      C  Port Harcourt        Member  Female
#  327         NaN  233-67-5758      C  Port Harcourt        Normal    Male
#
#                 Product line  Unit price  Quantity    Tax 5%      Total  \
# ...

# %%
len(Branch_C)
# Out:
# 1

# %%
PortHarcourt_branch = Branch_C[0]

# %%
PortHarcourt_branch
# Out:
#      Unnamed: 0   Invoice ID Branch           City Customer type  Gender  \
# 0           NaN  226-31-3081      C  Port Harcourt        Normal  Female
# 1           NaN  699-14-3026      C  Port Harcourt        Normal    Male
# 2           NaN  315-22-5665      C  Port Harcourt        Normal  Female
# 3           NaN  300-71-4605      C  Port Harcourt        Member    Male
# 4           NaN  183-56-6882      C  Port Harcourt        Member  Female
# ..          ...          ...    ...            ...           ...     ...
# 323         NaN  148-41-7930      C  Port Harcourt        Normal    Male
# 324         NaN  189-40-5216      C  Port Harcourt        Normal    Male
# 325         NaN  267-62-7380      C  Port Harcourt        Member    Male
# 326         NaN  652-49-6720      C  Port Harcourt        Member  Female
# 327         NaN  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# ...

# %%
del PortHarcourt_branch["Unnamed: 0"]

# %%
PortHarcourt_branch
# Out:
#       Invoice ID Branch           City Customer type  Gender  \
# 0    226-31-3081      C  Port Harcourt        Normal  Female
# 1    699-14-3026      C  Port Harcourt        Normal    Male
# 2    315-22-5665      C  Port Harcourt        Normal  Female
# 3    300-71-4605      C  Port Harcourt        Member    Male
# 4    183-56-6882      C  Port Harcourt        Member  Female
# ..           ...    ...            ...           ...     ...
# 323  148-41-7930      C  Port Harcourt        Normal    Male
# 324  189-40-5216      C  Port Harcourt        Normal    Male
# 325  267-62-7380      C  Port Harcourt        Member    Male
# 326  652-49-6720      C  Port Harcourt        Member  Female
# 327  233-67-5758      C  Port Harcourt        Normal    Male
#
#                Product line  Unit price  Quantity    Tax 5%      Total  \
# 0    Electronic accessories      5500.8         5   1375.20   28879.20
# 1    Electronic accessories     30740.4         7  10759.14  225941.94
# ...

# %%
PortHarcourt_branch.insert(loc = 0, column = "Serial_Number", value = np.arange(673, 1001))

# %%
PortHarcourt_branch
# Out:
#      Serial_Number   Invoice ID Branch           City Customer type  Gender  \
# 0              673  226-31-3081      C  Port Harcourt        Normal  Female
# 1              674  699-14-3026      C  Port Harcourt        Normal    Male
# 2              675  315-22-5665      C  Port Harcourt        Normal  Female
# 3              676  300-71-4605      C  Port Harcourt        Member    Male
# 4              677  183-56-6882      C  Port Harcourt        Member  Female
# ..             ...          ...    ...            ...           ...     ...
# 323            996  148-41-7930      C  Port Harcourt        Normal    Male
# 324            997  189-40-5216      C  Port Harcourt        Normal    Male
# 325            998  267-62-7380      C  Port Harcourt        Member    Male
# 326            999  652-49-6720      C  Port Harcourt        Member  Female
# 327           1000  233-67-5758      C  Port Harcourt        Normal    Male
#
# ...

# %% [markdown]
# **COMBINE THE THREE DATASETS**
#
# CONCATENATION
# Key: Abuja,Lagos and PortHarcourt respectively.

# %%
XYZ_Company_Datas = pd.concat([Abuja_branch,Lagos_branch,PortHarcourt_branch], keys =["Abuja","Lagos","PortHarcourt"])

# %%
XYZ_Company_Datas
# Out:
#                   Serial_Number   Invoice ID Branch           City  \
# Abuja        0                1  692-92-5582      B          Abuja
#              1                2  351-62-0822      B          Abuja
#              2                3  529-56-3974      B          Abuja
#              3                4  299-46-1805      B          Abuja
#              4                5  319-50-3348      B          Abuja
# ...                         ...          ...    ...            ...
# PortHarcourt 323            996  148-41-7930      C  Port Harcourt
#              324            997  189-40-5216      C  Port Harcourt
#              325            998  267-62-7380      C  Port Harcourt
#              326            999  652-49-6720      C  Port Harcourt
#              327           1000  233-67-5758      C  Port Harcourt
#
#                  Customer type  Gender            Product line  Unit price  \
# Abuja        0          Member  Female      Food and beverages     19742.4
# ...

# %% [markdown]
# **SAVE THE COMBINED DATESET TO CSV**

# %%
XYZ_Company_Datas.to_csv("XYZ_Company_Dataset.csv")

# %% [markdown]
# **DATA EXPLORATION**

# %%
XYZ_Company_Datas.head()   # Head method to view first few rows of the dataset
# Out:
#          Serial_Number   Invoice ID Branch   City Customer type  Gender  \
# Abuja 0              1  692-92-5582      B  Abuja        Member  Female
#       1              2  351-62-0822      B  Abuja        Member  Female
#       2              3  529-56-3974      B  Abuja        Member    Male
#       3              4  299-46-1805      B  Abuja        Member  Female
#       4              5  319-50-3348      B  Abuja        Normal  Female
#
#                    Product line  Unit price  Quantity    Tax 5%      Total  \
# Abuja 0      Food and beverages     19742.4         3   2961.36   62188.56
#       1     Fashion accessories      5212.8         4   1042.56   21893.76
#       2  Electronic accessories      9183.6         4   1836.72   38571.12
#       3       Sports and travel     33739.2         6  10121.76  212556.96
#       4      Home and lifestyle     14508.0         2   1450.80   30466.80
#
#               Date   Time Payment      cogs  gross margin percentage  \
# ...

# %%
XYZ_Company_Datas.shape  #  To check the number of rows and columns present in the data using the shape attribute.
# Out:
# (1000, 18)

# %%
XYZ_Company_Datas.columns # To generate the names of the columns using the columns attribute
# Out:
# Index(['Serial_Number', 'Invoice ID', 'Branch', 'City', 'Customer type',
#        'Gender', 'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total',
#        'Date', 'Time', 'Payment', 'cogs', 'gross margin percentage',
#        'gross income', 'Rating'],
#       dtype='object')

# %%
XYZ_Company_Datas.describe() # describe function to generate the statistical summary of the dataframe
# Out:
#        Serial_Number    Unit price     Quantity        Tax 5%          Total  \
# count    1000.000000   1000.000000  1000.000000   1000.000000    1000.000000
# mean      500.500000  20041.966800     5.510000   5536.572840  116268.029640
# std       288.819436   9538.066205     2.923431   4215.177173   88518.720636
# min         1.000000   3628.800000     1.000000    183.060000    3844.260000
# 25%       250.750000  11835.000000     3.000000   2132.955000   44792.055000
# 50%       500.500000  19882.800000     5.000000   4351.680000   91385.280000
# 75%       750.250000  28056.600000     8.000000   8080.290000  169686.090000
# max      1000.000000  35985.600000    10.000000  17874.000000  375354.000000
#
#                 cogs  gross margin percentage  gross income      Rating
# count    1000.000000             1.000000e+03   1000.000000  1000.00000
# mean   110731.456800             4.761905e+00   5536.572840     6.97270
# ...

# %%
XYZ_Company_Datas.isnull()  #  check for Missing values
# Out:
#                   Serial_Number  Invoice ID  Branch   City  Customer type  \
# Abuja        0            False       False   False  False          False
#              1            False       False   False  False          False
#              2            False       False   False  False          False
#              3            False       False   False  False          False
#              4            False       False   False  False          False
# ...                         ...         ...     ...    ...            ...
# PortHarcourt 323          False       False   False  False          False
#              324          False       False   False  False          False
#              325          False       False   False  False          False
#              326          False       False   False  False          False
#              327          False       False   False  False          False
#
#                   Gender  Product line  Unit price  Quantity  Tax 5%  Total  \
# ...

# %%
XYZ_Company_Datas.isnull().sum()
# Out:
# Serial_Number              0
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
XYZ_Company_Datas.notnull().sum()
# Out:
# Serial_Number              1000
# Invoice ID                 1000
# Branch                     1000
# City                       1000
# Customer type              1000
# Gender                     1000
# Product line               1000
# Unit price                 1000
# Quantity                   1000
# Tax 5%                     1000
# Total                      1000
# Date                       1000
# Time                       1000
# Payment                    1000
# cogs                       1000
# gross margin percentage    1000
# gross income               1000
# Rating                     1000
# dtype: int64

# %%
XYZ_Company_Datas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1000 entries, ('Abuja', 0) to ('PortHarcourt', 327)
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Serial_Number            1000 non-null   int64
#  1   Invoice ID               1000 non-null   object
#  2   Branch                   1000 non-null   object
#  3   City                     1000 non-null   object
#  4   Customer type            1000 non-null   object
#  5   Gender                   1000 non-null   object
#  6   Product line             1000 non-null   object
#  7   Unit price               1000 non-null   float64
#  8   Quantity                 1000 non-null   int64
#  9   Tax 5%                   1000 non-null   float64
#  10  Total                    1000 non-null   float64
#  11  Date                     1000 non-null   object
#  12  Time                     1000 non-null   object
# ...

# %% [markdown]
# **DEALING WITH DATETIME FEATURES**
#
# The to_datetime() is used to convert the date column to datetime
#
# We check the datatype to confirm if it's in datetime
#
# Accurate conversion of the time column & prints appropriate data type
#
# Accurate extraction of the Day, Month, Year & Hour features
#
# The numbers of unique hours of sales in the supermarket are accurately determined.
#
# Result that shows an array that contains the unique sales hours.

# %%
import datetime as dt

# %%
XYZ_Company_Datas['Date']= pd.to_datetime(XYZ_Company_Datas['Date'])

# %%
XYZ_Company_Datas['Date']
# Out:
# Abuja         0     2019-02-20
#               1     2019-02-06
#               2     2019-03-09
#               3     2019-01-15
#               4     2019-03-11
#                        ...
# PortHarcourt  323   2019-01-23
#               324   2019-01-09
#               325   2019-03-29
#               326   2019-02-18
#               327   2019-01-29
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
type(XYZ_Company_Datas['Date'])
# Out:
# pandas.core.series.Series

# %%
XYZ_Company_Datas['Time']= pd.to_datetime(XYZ_Company_Datas['Time'])

# %%
XYZ_Company_Datas['Time']
# Out:
# Abuja         0     2022-04-07 13:27:00
#               1     2022-04-07 18:07:00
#               2     2022-04-07 17:03:00
#               3     2022-04-07 16:19:00
#               4     2022-04-07 15:30:00
#                             ...
# PortHarcourt  323   2022-04-07 10:33:00
#               324   2022-04-07 11:40:00
#               325   2022-04-07 19:12:00
#               326   2022-04-07 11:40:00
#               327   2022-04-07 13:46:00
# Name: Time, Length: 1000, dtype: datetime64[ns]

# %%
type(XYZ_Company_Datas['Time'])
# Out:
# pandas.core.series.Series

# %%
 XYZ_Company_Datas['Day'] = XYZ_Company_Datas['Date'].dt.day

# %%
Newday =  XYZ_Company_Datas['Day']

# %%
Newday
# Out:
# Abuja         0      20
#               1       6
#               2       9
#               3      15
#               4      11
#                      ..
# PortHarcourt  323    23
#               324     9
#               325    29
#               326    18
#               327    29
# Name: Day, Length: 1000, dtype: int64

# %%
XYZ_Company_Datas['Month'] = XYZ_Company_Datas['Date'].dt.month

# %%
Newmonth = XYZ_Company_Datas['Month']

# %%
Newmonth
# Out:
# Abuja         0      2
#               1      2
#               2      3
#               3      1
#               4      3
#                     ..
# PortHarcourt  323    1
#               324    1
#               325    3
#               326    2
#               327    1
# Name: Month, Length: 1000, dtype: int64

# %%
XYZ_Company_Datas['Year'] = XYZ_Company_Datas['Date'].dt.year

# %%
Newyear = XYZ_Company_Datas['Year']

# %%
Newyear
# Out:
# Abuja         0      2019
#               1      2019
#               2      2019
#               3      2019
#               4      2019
#                      ...
# PortHarcourt  323    2019
#               324    2019
#               325    2019
#               326    2019
#               327    2019
# Name: Year, Length: 1000, dtype: int64

# %%
XYZ_Company_Datas['Hour'] = XYZ_Company_Datas['Time'].dt.hour

# %%
Newhour = XYZ_Company_Datas['Hour']

# %%
Newhour
# Out:
# Abuja         0      13
#               1      18
#               2      17
#               3      16
#               4      15
#                      ..
# PortHarcourt  323    10
#               324    11
#               325    19
#               326    11
#               327    13
# Name: Hour, Length: 1000, dtype: int64

# %% [markdown]
# **UNIQUE VALUES IN COLUMNS**
# The appropriate method to generate the unique values in the categorical columns
#
# Count figure of the categorical values using the value_counts() method will be generated

# %%
XYZ_Company_Datas
# Out:
#                   Serial_Number   Invoice ID Branch           City  \
# Abuja        0                1  692-92-5582      B          Abuja
#              1                2  351-62-0822      B          Abuja
#              2                3  529-56-3974      B          Abuja
#              3                4  299-46-1805      B          Abuja
#              4                5  319-50-3348      B          Abuja
# ...                         ...          ...    ...            ...
# PortHarcourt 323            996  148-41-7930      C  Port Harcourt
#              324            997  189-40-5216      C  Port Harcourt
#              325            998  267-62-7380      C  Port Harcourt
#              326            999  652-49-6720      C  Port Harcourt
#              327           1000  233-67-5758      C  Port Harcourt
#
#                  Customer type  Gender            Product line  Unit price  \
# Abuja        0          Member  Female      Food and beverages     19742.4
# ...

# %%
Newhour.unique()
# Out:
# array([13, 18, 17, 16, 15, 10, 12, 19, 14, 11, 20])

# %%
Newhour.nunique()
# Out:
# 11

# %%
categorical_columns = [col for col in XYZ_Company_Datas.columns if XYZ_Company_Datas[col].dtype == "object" ]
categorical_columns
# Out:
# ['Invoice ID',
#  'Branch',
#  'City',
#  'Customer type',
#  'Gender',
#  'Product line',
#  'Payment']

# %%
XYZ_Company_Datas['Branch'].unique().tolist()
# Out:
# ['B', 'A', 'C']

# %%
print("Total Number of unique values in the Branch Column : {}". format(len(XYZ_Company_Datas['Branch'].unique().tolist())))
# Out:
# Total Number of unique values in the Branch Column : 3

# %%
print("Total Number of unique values in the Quantity Column : {}". format(len(XYZ_Company_Datas['Quantity'].unique().tolist())))
# Out:
# Total Number of unique values in the Quantity Column : 10

# %%
XYZ_Company_Datas['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %% [markdown]
# **AGGREGATION WITH GROUPBY**
#
# A groupby object with the "City Column", and aggregation function of sum and mean.
#
# A table that shows the gross income of each city, and determines the city with the highest total gross income.
#
# Optional - Use of appropriate methods & descriptions to explore other columns such as Unit Price, Quantity.

# %%
XYZ_Company_Datas.head()
# Out:
#          Serial_Number   Invoice ID Branch   City Customer type  Gender  \
# Abuja 0              1  692-92-5582      B  Abuja        Member  Female
#       1              2  351-62-0822      B  Abuja        Member  Female
#       2              3  529-56-3974      B  Abuja        Member    Male
#       3              4  299-46-1805      B  Abuja        Member  Female
#       4              5  319-50-3348      B  Abuja        Normal  Female
#
#                    Product line  Unit price  Quantity    Tax 5%  ...  \
# Abuja 0      Food and beverages     19742.4         3   2961.36  ...
#       1     Fashion accessories      5212.8         4   1042.56  ...
#       2  Electronic accessories      9183.6         4   1836.72  ...
#       3       Sports and travel     33739.2         6  10121.76  ...
#       4      Home and lifestyle     14508.0         2   1450.80  ...
#
#                        Time Payment      cogs gross margin percentage  \
# ...

# %%
City_grp = XYZ_Company_Datas.groupby('City')

# %%
City_grp

# %%
City_grp.sum()
# Out:
#                Serial_Number  Unit price  Quantity      Tax 5%        Total  \
# City
# Abuja                  55278   6652396.8      1820  1820531.52  38231161.92
# Lagos                 170850   6705176.4      1859  1820577.78  38232133.38
# Port Harcourt         274372   6684393.6      1831  1895463.54  39804734.34
#
#                      cogs  gross margin percentage  gross income  Rating  \
# City
# Abuja          36410630.4              1580.952381    1820531.52  2263.6
# Lagos          36411555.6              1619.047619    1820577.78  2389.2
# Port Harcourt  37909270.8              1561.904762    1895463.54  2319.9
#
#                 Day  Month    Year  Hour
# City
# Abuja          5068    665  670308  5029
# Lagos          5232    688  686460  4987
# Port Harcourt  4956    640  662232  4894

# %%
City_grp.mean()
# Out:
#                Serial_Number    Unit price  Quantity       Tax 5%  \
# City
# Abuja                  166.5  20037.339759  5.481928  5483.528675
# Lagos                  502.5  19721.107059  5.467647  5354.640529
# Port Harcourt          836.5  20379.248780  5.582317  5778.852256
#
#                        Total           cogs  gross margin percentage  \
# City
# Abuja          115154.102169  109670.573494                 4.761905
# Lagos          112447.451118  107092.810588                 4.761905
# Port Harcourt  121355.897378  115577.045122                 4.761905
#
#                gross income    Rating        Day     Month    Year       Hour
# City
# Abuja           5483.528675  6.818072  15.265060  2.003012  2019.0  15.147590
# Lagos           5354.640529  7.027059  15.388235  2.023529  2019.0  14.667647
# Port Harcourt   5778.852256  7.072866  15.109756  1.951220  2019.0  14.920732

# %%
 City_grp.agg({"gross income":["sum","mean","max"]})
# Out:
#               gross income
#                        sum         mean      max
# City
# Abuja           1820531.52  5483.528675  17528.4
# Lagos           1820577.78  5354.640529  17816.4
# Port Harcourt   1895463.54  5778.852256  17874.0

# %%
City_grp["gross income"].sum().sort_values(ascending=False)
# Out:
# City
# Port Harcourt    1895463.54
# Lagos            1820577.78
# Abuja            1820531.52
# Name: gross income, dtype: float64

# %%
City_grp["gross income"].mean().sort_values(ascending=False)
# Out:
# City
# Port Harcourt    5778.852256
# Abuja            5483.528675
# Lagos            5354.640529
# Name: gross income, dtype: float64

# %% [markdown]
# **DATA VISUALIZATION**
#
# Appropriate use of countplot to determine the branch with the highest sales record.
#
# Appropriate use of countplot to determine the most used payment method & city with the most sales.
#
# Appropriate use of countplot to determine the highest & lowest sold product line.
#
# Result that shows the Payment channel used by most customers to pay for each product line. Chart should also show the "product line" column on the Y-axis, and the "hue" parameter for the "Payment" column.

# %%
sns.countplot(x='Quantity', hue='City', data=XYZ_Company_Datas).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.countplot(x='Payment', hue='City', data=XYZ_Company_Datas).set_title("Payment Method")
# Out:
# Text(0.5, 1.0, 'Payment Method')

# %%
sns.countplot(y='Product line', data=XYZ_Company_Datas).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.countplot(y='Product line', hue='Payment', data=XYZ_Company_Datas).set_title("Product analysis")
# Out:
# Text(0.5, 1.0, 'Product analysis')

# %%
sns.countplot(x='Payment', hue='Branch', data=XYZ_Company_Datas).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.boxplot(x='Branch', y='gross income', data=XYZ_Company_Datas).set_title("Sales Records")
# Out:
# Text(0.5, 1.0, 'Sales Records')

# %%
sns.catplot(x='Product line', y='Quantity', hue='Gender', data=XYZ_Company_Datas, aspect=4)

# %%
sns.catplot(x='Product line', y='Total', hue='Gender', data=XYZ_Company_Datas, aspect=4)

# %%
sns.catplot(x='Product line',y='Quantity', units='Product line per unit price',data=XYZ_Company_Datas, aspect=4)

# %%
sns.catplot(x='Product line',y='Quantity', units='product line per Quantity', data=XYZ_Company_Datas, aspect=4)

# %% [markdown]
# **INSIGHTS**
#
# during data wrangling i was ab le to have clearer picture of some functions in data analysis, which are very vital when it comes to analysis. some of it are the visualization, null value, unique value, Mean and standard deviation as listed below.

# %% [markdown]
# Visualisation
#
# this  visualising the data helps in decision-making, helps to inerrelate the data to find

# %% [markdown]
# **Unique()-value**T
#
# his function is used to find the unique elements of an array. it returns the sorted unique elements of an array.

# %% [markdown]
# **Mean() function:**
#
# this is an important measure in the data analysis that plays vital roles in the decision making. B

# %% [markdown]
# **Null-value:**
#
# A NULL value is a special marker used in data analysis to indicate that a data value does not exist in the datasets. its a placeholder to denote values that are missing or that we do not know.

# %% [markdown]
# **Groupby()**
#
# groupby is used for grouping data according to the categories and apply a function to the categories. it also helps to aggregiate data efficiently during data analysis. it also helps to get an overview of the dataset. it makes it easier to explore the dataset and unveil the underline relationships among variables.

# %% [markdown]
# **Future Work**
#
# one of the task that might be included in future work will be stretching on working with missing files, iterations, replacing strings. more works on visualizations like distplot(), swarmplot(), pointplot() and et al.

# %% [markdown]
# **Standout Section**
#
# since data visualization is vital part of data analysis. more seaborn functions was used to visualize dataset baseon their variance. for example: sns.catplot(x='Product line',y='Quantity', Units='product line per Quantity', data=df, aspect=4, kind='point')
#
# catplots was used to visualise the analysis in product line and quantity: that is product line per quantity.
#
# sns.boxplot(x='Branch', y='gross income', data=df).set_title("Sales Records") also Boxplot also used to visualise the analysis of gross income per branch.
#
# sns.countplot(x='Payment', hue='Branch', data=df).set_title("Sales Records") countplot also used to visualise the analysis of payment method most used in branches

# %% [markdown]
# **Executive Summary**
